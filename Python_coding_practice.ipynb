# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhiSrvstv/Python_interview_coding_questions/blob/main/Python_coding_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Count the Characters
# Easy
# Imagine you are developing a text analysis tool for a messaging app. One of the features you want to implement is the ability to count how often each character (letters, digits, spaces, and punctuation marks) appears in a given message.
#
# Your task is to write a simple Python program that takes a message from the user and counts the frequency of each character, including letters, digits, spaces, and special characters.
#
# Note : The program should take a user’s message as input and output a dictionary with characters as keys and their respective frequencies as values.
#
# Example 1:
# Input:
# google.com
#
# Output:
# {'g': 2, 'o': 3, 'l': 1, 'e': 1, '.': 1, 'c': 1, 'm': 1}
#
# Explanation:
# In the string "google.com", ‘g’ appears 2 times, ‘o’ 3 times, ‘l’ 1 time, ‘e’ 1 time, ‘.’ 1 time, ‘c’ 1 time, and ‘m’ 1 time.
#
# Example 2:
# Input:
# AlmaBetter
#
# Output:
# {'a': 2, 'l': 1, 'm': 1, 'b': 1, 'e': 2, 't': 2, 'r': 1}
#
# Explanation:
# In the string "AlmaBetter", ‘a’ appears 2 times, ‘l’ 1 time, ‘m’ 1 time, ‘b’ 1 time, ‘e’ 2 times, ‘t’ 2 times, and ‘r’ 1 time.
#
# Example 3:
# Input:
# Data Scientist
#
# Output:
# {'d': 1, 'a': 2, 't': 3, ' ': 1, 's': 2, 'c': 1, 'i': 2, 'e': 1, 'n': 1}
#
# Explanation:
# In the string "Data Scientist", ‘D’ appears 1 time, ‘a’ 2 times, ‘t’ 3 times, space ' ' appears 1 time, ‘S’ 1 time, ‘c’ 1 time, ‘i’ 2 times, ‘e’ 1 time, and ‘n’ 1 time.
#
# ## 2. Check String Start with Character
# Easy
# Write a Python program using a lambda function to determine whether a given string starts with a specified character. The program should accept two inputs: the string to check and the character. If the string starts with the given character, return True; otherwise, return False.
#
# Note : The program should handle both upper and lower case characters, and treat them as different (i.e., case-sensitive check).
#
# Example 1:
# Input:
# Python
#
# P
#
# Output:
# True
#
# Explanation:
# The string is "Python", and the character to check is 'P'. The lambda function checks whether the first character of the string matches 'P'. Since the string starts with 'P', the output is True.
#
# Example 2:
# Input:
# Java
#
# P
#
# Output:
# False
#
# Explanation:
# The string is "Java", and the character to check is 'Z'. The lambda function checks if the first character of the string matches 'Z'. Since the string starts with 'J' and not 'Z', the output is False.
#
# Example 3:
# Input:
# Almabetter
#
# a
#
# Output:
# False
#
# Explanation:
# The string is "Almabetter", and the character to check is 'a'. The lambda function is case-sensitive, so it checks if the first character is a lowercase 'a'. Since the string starts with an uppercase 'A', the output is False.
#
# ##3. Race for the Armstrong Award
# Easy
# In a maths competition, the Armstrong award would be presented to the one who would first tell the Armstrong number among all given numbers. Thus, write a program for Sam in Python to help him won the award.
#
# What is Armstrong Number?
#
# It is a number which is equal to the sum of cube of its digits. For eg: 153, 370 etc.
#
# Let's take 153 for an example
#
# First calculate the cube of its each digits
#
# 1^3 = (1 * 1 * 1) = 1
#
# 5^3 = (5 * 5 * 5) = 125
#
# 3^3= (3 * 3 * 3) = 27
#
# Now add the cube
#
# 1+125+27 = 153
#
# It means 153 is an Armstrong Number.
#
# Example 1:
# Input:
# 153
#
# Output:
# Number is Armstrong
#
# Explanation:
# 1³ + 5³ + 3³ = 1 + 125 + 27 = 153
#
# Example 2:
# Input:
# 450
#
# Output:
# Number is not Armstrong
#
# Explanation:
# 4³ + 5³ + 0³ = 64 + 125 + 0 = 189 (not equal to 450)
#
# Example 3:
# Input:
# 9474
#
# Output:
# Number is Armstrong
#
# Explanation:
# 9⁴ + 4⁴ + 7⁴ + 4⁴ = 6561 + 256 + 2401 + 256 = 9474
#
# ##4. Compute Partial Harmonic Sum
# Easy
# Write a Python program to calculate the harmonic sum of n−1, where n is a positive integer provided as input.
#
# The harmonic sum, denoted as H(n) is the sum of the reciprocals of the first n positive integers. For this question, you are required to compute the sum up to n−1. Mathematically, the harmonic sum for n−1 is given by:
#
#
#
# Note: The harmonic sum is the sum of reciprocals of the positive integers
#
# Example 1:
# Input:
# 4
#
# Output:
# 1.8333333333333333
#
# Explanation:
# H(4-1) = 1 + 1/2 + 1/3
#
# H(3) =1.8333333333333333
#
# Example 2:
# Input:
# 6
#
# Output:
# 2.283333333333333
#
# Explanation:
# H(6-1) = 1 + 1/2 + 1/3 + 1/4 + 1/5
#
# H(5) =2.283333333333333
#
# Example 3:
# Input:
# 7
#
# Output:
# 2.4499999999999997
#
# Explanation:
# H(7-1) = 1 + 1/2 + 1/3 + 1/4 + 1/5 + 1/6
#
# H(6) = 2.4499999999999997
#
# ##5. Mingle to Single : Repeated Digit Sum
# Easy
# Imagine You are a software developer working for a game company. In a math-based competition, players are given a large positive integer as their unique code. The goal is to simplify this number by repeatedly adding its digits until a single-digit number is reached. This final single-digit number will determine the player's prize.
#
# Your task is to write a Python program that takes a positive integer as input and repeatedly sums its digits until a single digit remains.
#
# Example 1:
# Input:
# 7548
#
# Output:
# Step-1 Sum: 24
#
# Step-2 Sum: 6
#
# Explanation:
# Step-1 ---> Sum = 7+5+4+8= 24
#
# Step-2 ---> Sum = 2+4 = 6
#
# Example 2:
# Input:
# 123456
#
# Output:
# Step-1 Sum: 21
#
# Step-2 Sum: 3
#
# Explanation:
# Step-1 ---> Sum = 1+2+3+4+5+6= 21
#
# Step-2 ---> Sum = 2+1 = 3
#
# Example 3:
# Input:
# 72314
#
# Output:
# Step-1 Sum: 17
#
# Step-2 Sum: 8
#
# Explanation:
# Step-1 ---> Sum = 7+2+3+1+4 = 17
#
# Step-2 ---> Sum = 1 + 7 = 8
#
# ##6. Identify Words with Prime Lengths
# Easy
# Imagine you're helping a teacher grade a language test. In one of the tasks, students were asked to identify and list all the words from a passage that have a length equal to a prime number. Your task is to write a Python program that does this automatically.
#
# The program will take a sentence or passage as input and output all the words whose length is a prime number.
#
# Note: A prime number is a number greater than 1 that has no divisors other than 1 and itself.
#
# Example 1:
# Input:
# The quick brown fox jumps over the lazy dog
#
# Output:
# The quick brown fox jumps the
#
# Explanation:
# Word Lengths "The" → 3 letters (prime) "quick" → 5 letters (prime) "brown" → 5 letters (prime) "fox" → 3 letters (prime) "jumps" → 5 letters (prime) "over" → 4 letters (not prime) "the" → 3 letters (prime) "lazy" → 4 letters (not prime) "dog" → 3 letters (prime)
#
# Prime-length words: The quick brown fox jumps the
#
# Example 2:
# Input:
# Welcome to the wonderful world of coding
#
# Output:
# Welcome to the world of
#
# Explanation:
# Word Lengths "Welcome" → 7 letters (prime) "to" → 2 letters (prime) "the" → 3 letters (prime) "wonderful" → 9 letters (not prime) "world" → 5 letters (prime) "of" → 2 letters (prime) "coding" → 6 letters (not prime)
#
# Prime-length words: "Welcome", "to", "the", "world", "of" all have prime lengths.
#
# Example 3:
# Input:
# Hello, world! Python is amazing and fun
#
# Output:
# Hello world is amazing and fun
#
# Explanation:
# Word lengths (ignoring punctuation): "Hello" → 5 letters (prime) "world" → 5 letters (prime) "Python" → 6 letters (not prime) "is" → 2 letters (prime) "amazing" → 7 letters (prime) "and" → 3 letters (prime) "fun" → 3 letters (prime)
#
# Prime-length words: "Hello", "world", "is", "amazing", "and", "fun" all have prime lengths.

# %% [markdown]
# **HARD**
#
#
# ##1. You are working in a logistics company that categorizes product codes based on their composition. Each product has a unique identifier, and some identifiers are formed by multiplying exactly three prime numbers together. Your task is to develop a Python program that helps the company identify which product codes (from 1 to n) are created using exactly three prime numbers.
#
# Write a Python program that:
#
#
# 1.	Takes an integer n as input, representing the maximum product code number.
# 2.	Finds all product codes between 1 and n that can be represented by multiplying exactly three prime numbers.
# 3.	Outputs each product code along with its three prime factors.
# Example 1:
# Input:
# 10
#
# Output:
# [[2, 2, 2]]
#
# Explanation:
# The list of prime numbers less than 10 is: [2, 3, 5, 7]
# These are the combinations [[2, 2, 2]] which gives product less than 10.
# Example 2:
# Input:
# 15
#
# Output:
# [[2, 2, 2], [2, 2, 3], [2, 3, 2], [3, 2, 2]]
#
# Explanation:
# The list of prime numbers less than 15 is: [2, 3, 5, 7,11,13]
# These are the combinations [[2, 2, 2], [2, 2, 3], [2, 3, 2], [3, 2, 2]] which gives product less than 15.
# Example 3:
# Input:
# 20
#
# Output:
# [[2, 2, 2], [2, 2, 3], [2, 2, 5], [2, 3, 2], [2, 3, 3], [2, 5, 2], [3, 2, 2], [3, 2, 3], [3, 3, 2], [5, 2, 2]]
#
# Explanation:
# The list of prime numbers less than 20 is: [2, 3, 5, 7,11,13,17,19]
# These are the combinations [[2, 2, 2], [2, 2, 3], [2, 2, 5], [2, 3, 2], [2, 3, 3], [2, 5, 2], [3, 2, 2], [3, 2, 3], [3, 3, 2], [5, 2, 2]] which gives product less than 20.

# %% [markdown]
# ##Find Closest Palindrome in Text
# Hard
# In many scenarios, finding patterns in text is essential for data processing and pattern recognition. One such task is identifying the closest palindrome from a given string, which can be particularly useful in applications involving text analysis, such as spell-checkers, pattern finders, or encryption.
#
# You are tasked with developing a Python program for a text-based search engine feature. The engine must be capable of finding the closest palindrome to a given string that represents a word. Palindromes are strings that read the same forwards and backwards, such as “madam” or “level.”
#
# Example 1:
# Input:
# cat
#
# Output:
# cac
#
# Explanation:
# In the string “cat,” the first and last characters (‘c’ and ‘t’) are not the same, so the logic adjusts the last character to match the first one. This forms the closest palindrome “cac,” but since the code only processes up to the calculated half point, the output becomes “ca.”
#
# Example 2:
# Input:
# madan
#
# Output:
# madam
#
# Explanation:
# In the string “madam,” the first and last characters match, but the middle characters are compared. The code incorrectly modifies the second-to-last character ‘m’ to ‘n,’ resulting in the output “madan.” This is due to a mistake in the logic when handling odd-length palindromes.
#
# Example 3:
# Input:
# racecbr
#
# Output:
# racecar
#
# Explanation:
# In the string “racecbr,” the first and last characters (‘r’ and ‘r’) match, but the second and second-to-last characters (‘a’ and ‘b’) do not. The logic adjusts the ‘b’ to ‘a’ and keeps matching the characters inward, eventually forming the palindrome “racecar.”

# %% [markdown]
# ##Print Space-Separated Characters with Counts
# Hard
# In some text processing or data formatting tasks, it’s essential to create a string where each character appears a specified number of times, separated by spaces. This can be used in applications such as encoding, formatting, or generating patterns.
#
# You are tasked with creating a Python program that generates a string consisting of characters separated by spaces, with each character repeated a specific number of times based on input counts. Given a list of characters and their corresponding counts, the program should return a space-separated string where each character appears as many times as specified in the input.
#
# Example 1:
# Input:
# {"f": 1, "o": 2}
#
# Output:
# f o o
#
# Explanation:
# The characters ‘f’ and ‘o’ (2 times) are repeated according to their counts and separated by spaces, resulting in: “f o o”.
#
# Example 2:
# Input:
# {'a': 1, 'p': 2, 'l': 1, 'e': 1}
#
# Output:
# a p p l e
#
# Explanation:
# The characters ‘a’, ‘p’ (2 times), ‘l’, and ‘e’ are repeated according to their counts and separated by spaces, resulting in: “a p p l e”.
#
# Example 3:
# Input:
# {'a': 2, 'l': 1, 'm': 1, 'b': 1, 'e': 2, 't': 2, 'r': 1}
#
# Output:
# a a l m b e e t t r
#
# Explanation:
# The characters ‘a’ (2 times), ‘l’, ‘m’, ‘b’, ‘e’ (2 times), ‘t’ (2 times), and ‘r’ are repeated according to their counts and separated by spaces, resulting in: “a a l m b e e t t r”.

# %% [markdown]
# ## Finding indices of Closest Temperatures
# Hard
# Imagine you work for a weather station, and you have a list of temperatures recorded throughout the day. Your job is to find which two temperatures in the list are the most similar (closest in value). Once you find the two closest temperatures, you need to tell their positions (indices) in the list.
#
# Note: "Closest", we mean finding two numbers that have the smallest difference between them.
#
# Example 1:
# Input:
# [1, 7, 9, 2, 10]
#
# Output:
# [0, 3]
#
# Explanation:
# The output [0, 3] represents the indices of the closest pair of numbers in the list [1, 7, 9, 2, 10]. The numbers at indices 0 and 3 are 1 and 2, which have the smallest difference (1).
#
# Example 2:
# Input:
# [5, 8, 12, 15, 7]
#
# Output:
# [4, 1]
#
# Explanation:
# The output [4, 1] represents the indices of the closest pair of numbers in the list [5,8,12,15,7]. The numbers at indices 4 and 1 are 7 and 8 which have the smallest difference (1).
#
# Example 3:
# Input:
# [100, 101, 99, 103, 105]
#
# Output:
# [0, 1]
#
# Explanation:
# The output [0, 1] represents the indices of the closest pair of numbers in the list [100, 101, 99, 103, 105]. The numbers at indices 0 and 1 are 100 and 101, which have the smallest difference (1).

# %% [markdown]
# ##Strange Sort: Alternating Smallest and Largest
# Hard
# In an amusement park ticket queue, visitors are sorted in a strange manner. The smallest number (representing the youngest visitor) stands first, followed by the oldest visitor. The next youngest visitor stands next, followed by the next oldest visitor, and so on. Write a Python program to sort a list of numbers in such a “strange sort,” where the first element is the smallest, the second is the largest, the third is the next smallest, and so on.
#
# Example 1:
# Input:
# [1, 3, 4, 5, 11]
#
# Output:
# [1, 11, 3, 5, 4]
#
# Explanation:
# The smallest element is 1, then the largest is 11, followed by the next smallest (3), the next largest (5), and the remaining element (4).
#
# Example 2:
# Input:
# [7, 2, 10, 4, 8]
#
# Output:
# [2, 10, 4, 8, 7]
#
# Explanation:
# The smallest element is 2, then the largest is 10, followed by the next smallest (4), the next largest (8), and the remaining element (7).
#
# Example 3:
# Input:
# [9, 15, 3, 12, 6, 1]
#
# Output:
# [1, 15, 3, 12, 6, 9]
#
# Explanation:
# The smallest element is 1, then the largest is 15, followed by the next smallest (3), the next largest (12), and so on.

# %% [markdown]
# ## Compute Depth of Matched Nested Parentheses
# Hard
# In a data structure where parentheses represent nested groups or levels (such as mathematical expressions or organizational hierarchies), it is essential to calculate the depth of each group. The depth of a group is determined by how many levels of nested parentheses it has. Write a Python program that computes the depth of each group of nested parentheses in a string, where groups are separated by spaces.
#
# Example 1:
# Input:
# ((())) () ((()))
#
# Output:
# [3, 1, 3]
#
# Explanation:
# The first group ((())) has a depth of 3, the second group () has a depth of 1, and the third group ((())) also has a depth of 3.
#
# Example 2:
# Input:
# (()) (()) () ((()()()))
#
# Output:
# [2, 2, 1, 3]
#
# Explanation:
# The first group (( )) has a depth of 2, the second group (()) has a depth of 2, the third group () has a depth of 1, and the fourth group ((()()()))has a depth of 3. The number of opening parentheses before encountering a closing parenthesis determines the depth for each group.
#
# Example 3:
# Input:
# ((( ))) ((()))
#
# Output:
# [3, 0, 3]
#
# Explanation:
# The first group ((( ))) has a maximum depth of 3, and the space between groups has no parentheses, contributing a depth of 0.The second group ((())) has a maximum depth of 3.

# %% [markdown]
# ## Total Salaries
# Easy
# Write an SQL query to fetch departments along with the total salaries paid for each of them.
#
# Input:
#
# Table-I: Worker
#
# Table-II: Bonus
#
# Table-III: Title
#
# Output:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Mary’s Client Email Formatter
# Easy
# Mary works in a customer relations department where she needs to send emails to clients. For each email, Mary needs to address the clients using their last name first, followed by their first name, separated by a space. To speed up this process, Mary wants to automate it with a Python program.
#
# Your task is to help Mary by writing a Python program that takes the first and last names of a client as input and prints them in reverse order (last name first, space , followed by the first name).
#
# Example 1:
# Input:
# Alice
#
# Johnson
#
# Output:
# Johson Alice
#
# Explanation:
# Johson + " " + Alice = Johson Alice
#
# Example 2:
# Input:
# John
#
# Doe
#
# Output:
# Doe John
#
# Explanation:
# Doe + " " + John = Doe John
#
# Example 3:
# Input:
# Anna
#
# Annabelle
#
# Output:
# Annabelle Anna
#
# Explanation:
# Annabelle + " " + Anna = Annabelle Anna

# %% [markdown]
# ## Find Nobel Prize Winners for 1970
# Easy
# Write a SQL query to retrieve the Nobel Prize winners for the year 1970 from the nobel_win table. The query should select the columns year, subject, and winner, and filter the results to only include entries where the year is 1970. Ensure the output is presented in the following format: year, subject, winner.
#
# Input
#
# Table: nobel_win
#
# Output
#
# ![image.png](
#
# )

# %% [markdown]
# ## Find Nobel Prize Details for Dennis Gabor
# Easy
# *In this exercise, you need to write a SQL query to locate the Nobel Prize details for the winner ‘Dennis Gabor’. The database table nobel_win contains information on various Nobel Prize winners. Your task is to retrieve the year and subject of the prize won by Dennis Gabor.
#
# Input
#
# Table: nobel_win
#
# Output
# ![image.png](data:image/png;base64,...)
